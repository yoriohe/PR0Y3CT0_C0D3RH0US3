# %% [markdown]
# # PREDICCION DE POTENCIALES BAJAS Y EXITOS ACADEMICOS

# %% [markdown]
# El conjunto de datos se creó en un proyecto que tiene como objetivo contribuir a la reducción del abandono y el fracaso académico en la educación superior, mediante el uso de técnicas de aprendizaje automático para identificar a los estudiantes en riesgo en una etapa temprana de su trayectoria académica, de modo que se puedan diseñar estrategias para apoyarlos. poner en su lugar.
# El conjunto de datos incluye información conocida en el momento de la inscripción de los estudiantes: trayectoria académica, demografía y factores socioeconómicos.
# El problema se formula como una tarea de clasificación en tres categorías (deserción, matriculados y egresados) al final de la duración normal del curso.
# Cada instancia es un estudiante.

# %% [markdown]
# El Dataset consta de 4424 instancias  y 36 Atributos

# %% [markdown]
# ATRIBUTOS:
# Estado Civil
# Modo de Solicitud
# Orden de Solicitud
# Curso
# Asistencia Diurna/Nocturna
# Calificación Anterior
# Calificación Anterior (nota)
# Nacionalidad
# Calificación de la Madre
# Calificación del Padre
# Ocupación de la Madre
# Ocupación del Padre
# Nota de Admisión
# Desplazado
# Necesidades Educativas Especiales
# Deudor
# Cuotas al día
# Género
# Beneficiario de Beca
# Edad al Matricularse
# Internacional
# Unidades Curriculares 1er sem (acreditadas)
# Unidades Curriculares 1er sem (inscritas)
# Unidades Curriculares 1er sem (evaluaciones)
# Unidades Curriculares 1er sem (aprobadas)
# Promedio de Notas 1er sem
# Unidades Curriculares 1er sem (sin evaluaciones)
# Unidades Curriculares 2do sem (acreditadas)
# Unidades Curriculares 2do sem (inscritas)
# Unidades Curriculares 2do sem (evaluaciones)
# Unidades Curriculares 2do sem (aprobadas)
# Promedio de Notas 2do sem
# Unidades Curriculares 2do sem (sin evaluaciones)
# Tasa de Desempleo
# Tasa de Inflación
# PIB

# %%
# Importamos las librerías a trabajar el set de datos para su corroboración
import numpy as np
import pandas as pd

# %%
#Leemos el archivo csv

df = pd.read_csv("C:/Users/yorio/OneDrive/DATA_SCIENCE_CODERHOUSE/Data Sets/DatasetsYorio/predict+students+dropout+and+academic+success.csv",sep=";")

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
#Analizo cantidad de variables  y verifico sus características
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...
