# %%
# Importamos las librerías a trabajar el set de datos para su corroboración
import numpy as np
import pandas as pd

# %%
#Leemos el archivo csv
df = pd.read_csv("C:/Users/yorio/OneDrive/DATA_SCIENCE_CODERHOUSE/Data Sets/DatasetsYorio/US_Accidents_2023.csv",sep=";")

# %%
df.head()
# Out:
#           ID   Source  Severity                     Start_Time Month  Year  \
# 0  A-3650461  Source1         2  2023-03-31 17:09:16.000000000  mar.  2023
# 1  A-3650462  Source1         2  2023-02-27 20:55:00.000000000  feb.  2023
# 2  A-3650463  Source1         2  2023-02-26 09:31:45.000000000  feb.  2023
# 3  A-3650464  Source1         2  2023-03-21 17:46:42.000000000  mar.  2023
# 4  A-3650465  Source1         2  2023-03-24 04:46:30.000000000  mar.  2023
#
#                         End_Time               Start_Lat       Start_Lng  \
# 0  2023-03-31 18:09:49.000000000              45.676.472     -94.174.568
# 1  2023-02-27 23:36:34.000000000              41.391.812     -75.467.365
# 2  2023-02-26 11:58:19.000000000              40.850.278      -7.394.614
# 3  2023-03-21 18:31:50.000000000           3.371.499.181  -8.430.018.783
# 4  2023-03-24 09:22:00.000000000  33.927.671.000.000.000    -118.266.385
#
#          End_Lat  ... Roundabout Station   Stop Traffic_Calming  \
# ...

# %%
#Analizo cantidad de variables  y verifico sus características
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246633 entries, 0 to 246632
# Data columns (total 48 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     246633 non-null  object
#  1   Source                 246633 non-null  object
#  2   Severity               246633 non-null  int64
#  3   Start_Time             246633 non-null  object
#  4   Month                  246633 non-null  object
#  5   Year                   246633 non-null  int64
#  6   End_Time               246633 non-null  object
#  7   Start_Lat              246633 non-null  object
#  8   Start_Lng              246633 non-null  object
#  9   End_Lat                246633 non-null  object
#  10  End_Lng                246633 non-null  object
#  11  Distance(mi)           246633 non-null  object
#  12  Description            246633 non-null  object
#  13  Street                 245863 non-null  object
# ...
